# %% [markdown]
# # 🎮 Jupyter Notebook: Explorando Vendas de Videogames
#
# **Bem-vindo(a)!** Neste notebook, vamos explorar um banco de dados com o ranking de vendas de videogames clássicos.
# O objetivo é usar o Pandas para descobrir quais jogos, plataformas e gêneros venderam mais!

# %%
# Célula 0: Configuração inicial (Rode isso primeiro!)
import pandas as pd
import matplotlib.pyplot as plt

# Carregando os dados (Certifique-se de que o arquivo .csv está na mesma pasta)
df = pd.read_csv('vendas_jogos.csv')

print('deu certo')
print(df.head())
# Out:
# deu certo
#    Ranking                  Nome     Plataforma   Ano        Gênero   Editora  \
# 0        1  Sonic the Hedgehog 2     Mega Drive  1992      Platform      Sega
# 1        2      Final Fantasy II           SNES  1991  Role-Playing    Square
# 2        3         Final Fantasy            NES  1987  Role-Playing    Square
# 3        4    Sonic the Hedgehog  Master System  1991      Platform      Sega
# 4        5   Donkey Kong Country           SNES  1994      Platform  Nintendo
#
#    Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 0                    16.65       10.82          2.73           9.84
# 1                    15.65       12.12          7.15           4.80
# 2                    12.45        7.68          8.53           5.99
# 3                    11.86        9.49          0.43          14.20
# 4                    14.44        9.57          8.02           2.44
#
#    Vendas Globais
# 0           29.22
# 1           27.60
# 2           26.97
# 3           26.49
# 4           24.90

# %% [markdown]
# ---
# ### 🟢 Nível 1: Conhecendo a Tabela (O Básico)
#
# **Exercício 1:**
# Mostre as **10 primeiras linhas** da tabela para ver como ela é.

# %%
# Seu código aqui
df.head(10)
# Out:
#    Ranking                             Nome     Plataforma   Ano  \
# 0        1             Sonic the Hedgehog 2     Mega Drive  1992
# 1        2                 Final Fantasy II           SNES  1991
# 2        3                    Final Fantasy            NES  1987
# 3        4               Sonic the Hedgehog  Master System  1991
# 4        5              Donkey Kong Country           SNES  1994
# 5        6  Zelda II: The Adventure of Link            NES  1987
# 6        7          Street Fighter II Turbo           SNES  1993
# 7        8                          Pac-Man         Arcade  1980
# 8        9                Super Mario World           SNES  1990
# 9       10                Super Mario Bros.            NES  1985
#
#          Gênero   Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  \
# 0      Platform      Sega                    16.65       10.82          2.73
# 1  Role-Playing    Square                    15.65       12.12          7.15
# 2  Role-Playing    Square                    12.45        7.68          8.53
# 3      Platform      Sega                    11.86        9.49          0.43
# 4      Platform  Nintendo                    14.44        9.57          8.02
# 5     Adventure  Nintendo                    10.24        7.31          5.81
# 6      Fighting    Capcom                    14.17       12.16          0.49
# 7          Misc     Namco                    12.10        9.11          0.89
# 8      Platform  Nintendo                    12.08        8.21          4.38
# 9      Platform  Nintendo                     9.84        8.55          3.85
#
#    Outras Vendas  Vendas Globais
# 0           9.84           29.22
# 1           4.80           27.60
# 2           5.99           26.97
# 3          14.20           26.49
# 4           2.44           24.90
# 5           8.75           24.80
# 6          10.02           24.68
# 7          10.22           23.21
# 8           6.48           22.94
# 9           5.34           19.03

# %% [markdown]
# **Exercício 2:**
# Agora, mostre as **5 últimas linhas** da tabela. Quem são os jogos que estão no finalzinho da lista?
#
# *Dica: Use o comando `.tail()`*

# %%
# Seu código aqui
df.tail(5)
# Out:
#     Ranking                  Nome  Plataforma   Ano    Gênero     Editora  \
# 95       96      Mortal Kombat II  Mega Drive  1993  Fighting     Acclaim
# 96       97               Kaboom!        2600  1981      Misc  Activision
# 97       98  Super Castlevania IV        SNES  1991  Platform      Konami
# 98       99            Mega Man 2         NES  1988    Action      Capcom
# 99      100     Kirby's Adventure         NES  1993  Platform    Nintendo
#
#     Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 95                     0.19        0.16          0.02           0.17
# 96                     0.12        0.09          0.01           0.10
# 97                     0.10        0.09          0.02           0.10
# 98                     0.09        0.07          0.01           0.06
# 99                     0.04        0.04          0.02           0.04
#
#     Vendas Globais
# 95            0.38
# 96            0.23
# 97            0.22
# 98            0.16
# 99            0.10

# %% [markdown]
# **Exercício 3:**
# Quantas linhas e quantas colunas tem o nosso banco de dados?
#
# *Dica: use o `.shape`*

# %%
# Seu código aqui
df.shape
# Out:
# (100, 11)

# %% [markdown]
# ---
# ### 🟡 Nível 2: Filtrando e Ordenando (Procurando Joias)
#
# A tabela já vem ordenada pelo Ranking, mas podemos organizar de outras formas.
#
# **Exercício 4:**
# Mostre apenas os jogos que venderam **mais de 1.0** na coluna `Vendas Globais`. Quantos jogos conseguiram essa façanha?

# %%
# Seu código aqui
df[df['Vendas Globais'] >1.0]
# Out:
#     Ranking                  Nome     Plataforma   Ano        Gênero  \
# 0         1  Sonic the Hedgehog 2     Mega Drive  1992      Platform
# 1         2      Final Fantasy II           SNES  1991  Role-Playing
# 2         3         Final Fantasy            NES  1987  Role-Playing
# 3         4    Sonic the Hedgehog  Master System  1991      Platform
# 4         5   Donkey Kong Country           SNES  1994      Platform
# ..      ...                   ...            ...   ...           ...
# 84       85              Defender           2600  1980          Misc
# 85       86        Wonder Boy III  Master System  1989     Adventure
# 86       87        Gunstar Heroes     Mega Drive  1993       Shooter
# 87       88         Double Dragon            NES  1988        Action
# 88       89          After Burner  Master System  1987       Shooter
#
#       Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  \
# 0        Sega                    16.65       10.82          2.73
# 1      Square                    15.65       12.12          7.15
# 2      Square                    12.45        7.68          8.53
# 3        Sega                    11.86        9.49          0.43
# 4    Nintendo                    14.44        9.57          8.02
# ..        ...                      ...         ...           ...
# 84      Atari                     0.67        0.40          0.07
# 85       Sega                     0.67        0.52          0.03
# 86       Sega                     0.49        0.35          0.08
# 87  Tradewest                     0.65        0.52          0.04
# 88       Sega                     0.50        0.34          0.05
#
#     Outras Vendas  Vendas Globais
# 0            9.84           29.22
# 1            4.80           27.60
# 2            5.99           26.97
# 3           14.20           26.49
# 4            2.44           24.90
# ..            ...             ...
# 84           0.44            1.18
# 85           0.45            1.15
# 86           0.53            1.10
# 87           0.40            1.09
# 88           0.48            1.03
#
# [89 rows x 11 columns]

# %% [markdown]
# **Exercício 5:**
# Vamos ver os jogos mais **antigos** da lista. Ordene a tabela pelo ano (`Ano`) de forma crescente (do mais antigo para o mais novo) e mostre apenas as 5 primeiras linhas do resultado.

# %%
# Seu código aqui
df.sort_values(by='Ano').head()
# Out:
#     Ranking            Nome Plataforma   Ano   Gênero     Editora  \
# 80       81          Combat       2600  1977  Shooter       Atari
# 44       45  Space Invaders     Arcade  1978  Shooter       Taito
# 60       61          Bridge       2600  1980     Misc  Activision
# 7         8         Pac-Man     Arcade  1980     Misc       Namco
# 45       46       Asteroids       2600  1980  Shooter       Atari
#
#     Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 80                     0.75        0.58          0.13           0.53
# 44                     1.77        1.10          0.26           1.71
# 60                     1.30        0.99          0.27           1.16
# 7                     12.10        9.11          0.89          10.22
# 45                     2.15        1.34          0.26           1.30
#
#     Vendas Globais
# 80            1.41
# 44            3.74
# 60            2.73
# 7            23.21
# 45            3.71

# %% [markdown]
# **Exercício 6:**
# Agora o contrário: quais são os jogos mais **recentes** da lista? Ordene pelo ano de forma decrescente e mostre os 5 primeiros.
#
# *Dica: Adicione o parâmetro `ascending=False` no sort_values*

# %%
# Seu código aqui
df.sort_values(by='Ano',ascending=False).head()
# Out:
#     Ranking                   Nome  Plataforma   Ano    Gênero   Editora  \
# 26       27       Kirby Super Star        SNES  1996  Platform  Nintendo
# 16       17  Donkey Kong Country 2        SNES  1995  Platform  Nintendo
# 29       30         Yoshi's Island        SNES  1995  Platform  Nintendo
# 38       39              Vectorman  Mega Drive  1995  Platform      Sega
# 52       53             Comix Zone  Mega Drive  1995    Action      Sega
#
#     Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 26                     2.03        1.48          0.98           1.81
# 16                     6.25        5.41          1.92           3.07
# 29                     2.80        1.82          0.81           1.09
# 38                     2.19        1.96          0.31           1.69
# 52                     1.85        1.28          0.04           1.41
#
#     Vendas Globais
# 26            4.82
# 16           11.24
# 29            4.70
# 38            4.19
# 52            3.30

# %% [markdown]
# ---
# ### 🟠 Nível 3: Curiosidades e Estatísticas Simples
#
# Vamos usar funções matemáticas básicas para entender a lista.
#
# **Exercício 7:**
# Qual é a **média das Vendas Globais** de todos os jogos? E qual é a média dos anos de lançamento?
#
# *Dica: Use o comando `.mean()` na coluna desejada.*

# %%
# Seu código aqui
media_jogos = df['Vendas Globais'].mean()
print(f"A média de Vendas Globais é {media_jogos}")
# Out:
# A média de Vendas Globais é 6.0492

# %% [markdown]
# **Exercício 8:**
# Quem é o jogo com a **maior Venda Global** da lista? E qual é esse valor?
# *(Dica: Ordene a coluna 'Vendas Globais' e veja qual fica no topo).*

# %%
# Seu código aqui

# %% [markdown]
# ---
# ### 🔴 Nível 4: Um pouco de Visualização (Gráficos)
#
# Uma imagem vale mais que mil palavras. Vamos criar gráficos simples.
#
# **Exercício 9:**
# Crie um **gráfico de barras** mostrando os 10 jogos com as maiores `Vendas Globais`.
# *Pergunta:* Quais jogos dominam o topo da lista?
#
# *Dica: Use `dataset.sort_values(by='Vendas Globais', ascending=False).head(10).plot(kind='bar', x='Nome', y='Vendas Globais')`*

# %%
# Seu código aqui

# %% [markdown]
# **Exercício 10:**
# Crie um **histograma** para ver como as `Vendas Globais` estão distribuídas. A maioria dos jogos vendeu perto de 0.5 ou 1.0?
#
# *Dica: Use `dataset['Vendas Globais'].plot(kind='hist', bins=20)`*

# %%
# Seu código aqui
